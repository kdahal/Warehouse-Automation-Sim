# %%
# %load_ext autoreload
from src.simulation_engine import SimulationEngine; engine = SimulationEngine()

# %%
results = engine.run_iteration(num_orders=200, iterations=10)

# %%
from src.metrics import generate_report
import matplotlib.pyplot as plt
summary, df = generate_report(results)
print(summary)
df.plot(x='iteration', y='throughput', kind='line')
plt.title('Throughput Validation Over Iterations')
plt.show()

# %%
df.to_csv('validation_results.csv')
throughput_plot.png
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('validation_results.csv')
#       2 throughput_plot.png
#
# NameError: name 'df' is not defined
